# %% [markdown]
# # Transfer Learning
#
# What is transfer learning?
# It means using a trained NN modle which is used to one thing, to train your own model targeted to do another thing
# All you have to do is change the output layer and use it to train on your own dataset
